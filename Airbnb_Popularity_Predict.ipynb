# %% [markdown]
# # Airbnb Popularity Predict
#
# In the second part, we will illustrate the use of multiple linear regression for finding the effect of important factors affecting the sale of Airbnb hosting.
# The data for the  is taken generously from Kaggle's [New York City Airbnb Open Data](https://www.kaggle.com/dgomonov/new-york-city-airbnb-open-data).
# For the second part, we will focus on the task of predicting the popularity of airbnb listing, which is indicated by the number of reviews from the dataset:
#
# <img src="airbnb.png" height="300" width="300">
#
#
# The factors we will be taking into considerations for the second part are: neighbourhood_group, neighbourhood, latitude, longitude, room_type, price, minimum_nights, availability_365.

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import preprocessing
from sklearn.metrics.pairwise import pairwise_kernels
import scipy
from sklearn import svm, linear_model
from sklearn.model_selection import GridSearchCV
import time
import seaborn as sns

# %%
df = pd.read_csv('AB_NYC_2019.csv',
                na_values='?',header=None)
df.columns = df.iloc[0]
df = df[1:]
df = df.dropna()
df.head()
# Out:
# C:\Users\zzw_e\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (0,2,6,7,9,10,11,13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# 0    id                                              name host_id  \
# 1  2539                Clean & quiet apt home by the park    2787
# 2  2595                             Skylit Midtown Castle    2845
# 4  3831                   Cozy Entire Floor of Brownstone    4869
# 5  5022  Entire Apt: Spacious Studio/Loft by central park    7192
# 6  5099         Large Cozy 1 BR Apartment In Midtown East    7322
#
# 0    host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 1         John            Brooklyn    Kensington  40.64749  -73.97237
# 2     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 4  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 5        Laura           Manhattan   East Harlem  40.79851  -73.94399
# 6        Chris           Manhattan   Murray Hill  40.74767    -73.975
#
# 0        room_type price minimum_nights number_of_reviews last_review  \
# 1     Private room   149              1                 9  2018-10-19
# 2  Entire home/apt   225              1                45  2019-05-21
# 4  Entire home/apt    89              1               270  2019-07-05
# 5  Entire home/apt    80             10                 9  2018-11-19
# 6  Entire home/apt   200              3                74  2019-06-22
#
# 0 reviews_per_month calculated_host_listings_count availability_365
# 1              0.21                              6              365
# 2              0.38                              2              355
# 4              4.64                              1              194
# 5              0.10                              1                0
# 6              0.59                              1              129

# %% [markdown]
# # Preprocess Data

# %%
xnames = ['neighbourhood_group','neighbourhood','latitude','longitude','room_type','price',
         'minimum_nights', 'calculated_host_listings_count','availability_365']
X = np.array(df[xnames])
ID = np.array(df['id'])
ID = ID.astype(int)
y = np.array(df['number_of_reviews'])
y = y.astype(int)
# Convert neighborhood to ascii code
neighbourhood_group = X[:,0]
for i in range(len(neighbourhood_group)):
    new = sum(ord(c) for c in neighbourhood_group[i])
    neighbourhood_group[i] = int(new)

# convert neighborhood to ascii code
neighbourhood = X[:,1]
for i in range(len(neighbourhood)):
    new = sum(ord(c) for c in neighbourhood[i])
    neighbourhood[i] = int(new)

# Convert room_type: Private room-0, Entire home/apt-1
room_type = X[:,4]
PRI_VAL = "Private room"
ENT_VAL = "Entire home/apt"
for i in range(len(room_type)):
    if room_type[i] == PRI_VAL:
        room_type[i] = 0
    elif room_type[i] == ENT_VAL:
        room_type[i] = 1
    else:
        room_type[i] = 2
X[:,2] = X[:,2].astype(float)
X[:,3] = X[:,3].astype(float)
X[:,5] = X[:,5].astype(int)
X[:,6] = X[:,6].astype(int)
X[:,7] = X[:,7].astype(int)
X[:,8] = X[:,8].astype(int)
print("Converted Dataset X:\n",X)
print("\nwith dimension:\n", X.shape)
df["room_type"] = room_type
df["neighbourhood_group"] = neighbourhood_group
df["neighborhood"] = neighbourhood
# Out:
# Converted Dataset X:
#  [[848 1056 40.64749 ... 1 6 365]
#  [924 738 40.75362 ... 1 2 355]
#  [848 1152 40.68514 ... 1 1 194]
#  ...
#  [1258 1042 40.54179 ... 1 1 87]
#  [521 950 40.80787 ... 1 1 40]
#  [848 832 40.69805 ... 1 1 1]]
#
# with dimension:
#  (38821, 9)

# %%
df["number_of_reviews"].describe()
# Out:
# count     38821
# unique      500
# top           1
# freq       3066
# Name: number_of_reviews, dtype: object

# %%
sns.set()
df["room_type"] = df["room_type"].astype(int)
df["neighbourhood_group"] = df["neighbourhood_group"].astype(int)
df["neighborhood"] = df["neighborhood"].astype(int)
df['number_of_reviews'] = df['number_of_reviews'].astype(int)
df['price'] = df['price'].astype(int)
df["calculated_host_listings_count"] = df["calculated_host_listings_count"].astype(int)
df['minimum_nights'] = df['minimum_nights'].astype(int)
df['latitude'] = df['latitude'].astype(float)
df['longitude'] = df['longitude'].astype(float)
df['availability_365'] = df['availability_365'].astype(int)
input_lst = ['neighbourhood_group','neighborhood','latitude','longitude','room_type','price',
         'minimum_nights', 'calculated_host_listings_count','availability_365','number_of_reviews']

# %%
corrmat = df.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True);

# %%
#saleprice correlation matrix
k = 6 #number of variables for heatmap
cols = corrmat.nlargest(k, 'number_of_reviews')['number_of_reviews'].index
cm = np.corrcoef(df[cols].values.T)
sns.set(font_scale=1.25)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)
plt.show()

# %%
sns.pairplot(df[input_lst], size = 2.5)
plt.show();

# %% [markdown]
# # Split data into a training and test set with a ratio of 2/3 - 1/3

# %%
nt = len(X)
ind_lst = np.random.permutation(nt)

ntr = len(ind_lst) * 2//3
ntr_lst = ind_lst[:ntr]
nts = len(ind_lst) - ntr
nts_lst = ind_lst[ntr:]

IDtr = ID[ntr_lst]
IDts = ID[nts_lst]

Xtr = np.matrix(X[[ntr_lst]], dtype='int')
Xts1 = np.matrix(X[[nts_lst]], dtype='int')
ytr = y[ntr_lst]
yts1 = y[nts_lst]
print("X training set:\n",Xtr)
print("\nX testing set:\n",Xts1)
print("\ny training set:\n",ytr)
print("\ny testing set:\n",yts1)
# Out:
# X training set:
#  [[ 848  740   40 ...   31    2  110]
#  [ 848 2460   40 ...   10    1  343]
#  [ 848  807   40 ...    1    4  134]
#  ...
#  [ 848 1266   40 ...    1    1   39]
#  [ 625  723   40 ...    1    2   90]
#  [ 625  723   40 ...    1    5   89]]
#
# X testing set:
#  [[ 924 1899   40 ...    2    1   22]
#  [ 625  832   40 ...    1    5   84]
#  [ 848 1269   40 ...    3    2    0]
#  ...
#  [ 848 1266   40 ...    2    1  214]
#  [ 848 1459   40 ...    2    2  160]
#  [ 848 1833   40 ...    5    6   94]]
#
# y training set:
#  [114  12  16 ...  11   2   4]
#
# y testing set:
#  [ 4 39  6 ... 11 13 89]

# %% [markdown]
# # Fit a Multi-Linear Model

# %%
def fit_mult_linear(X,y):
    """
    Given matrix of predictors X and target vector y fit for a multiple linear regression model under the squared loss.
    """
    nsamp = len(X)
    ones = np.ones((nsamp,1))
    X_orig = X
    X = np.hstack((ones,X_orig))
    Xmat=np.matrix(X)
    ymat=np.matrix(y)
    ymat=np.transpose(ymat)
    Xmatt=np.transpose(Xmat)
    beta=np.linalg.inv(Xmatt*Xmat)*Xmatt*ymat
    return beta

# %%
beta_lst = fit_mult_linear(Xtr, ytr)
beta0 = beta_lst[0]
beta1 = beta_lst[1:]
print("beta_lst:\n",beta_lst)
print("beta0:\n",beta0)
print("beta1:\n",beta1)
# Out:
# beta_lst:
#  [[ 1.29112608e+19]
#  [-1.45106446e+01]
#  [-5.30889526e+00]
#  [-3.27766445e+17]
#  [-1.04319364e+04]
#  [ 5.87302251e+02]
#  [-1.50273311e-01]
#  [-6.25987153e+00]
#  [-9.46700441e+00]
#  [ 9.49671766e-03]]
# beta0:
#  [[1.29112608e+19]]
# beta1:
#  [[-1.45106446e+01]
#  [-5.30889526e+00]
#  [-3.27766445e+17]
#  [-1.04319364e+04]
#  [ 5.87302251e+02]
#  [-1.50273311e-01]
#  [-6.25987153e+00]
#  [-9.46700441e+00]
#  [ 9.49671766e-03]]

# %%
nsamp = len(Xtr)
ones = np.ones((nsamp,1))
X_orig = Xtr
X = np.hstack((ones,X_orig))
Xmat=np.matrix(X)
ymat=np.matrix(ytr)
ymat=np.transpose(ymat)

ytr_pred = Xmat*beta_lst
lossm = np.linalg.norm(np.array(ymat - ytr_pred))**2

print("multiple variable loss="+"{:.2e}".format(lossm))
# Out:
# multiple variable loss=1.03e+39

# %% [markdown]
# # Measure the Fit on the Testing Dataset

# %%
beta_ts = fit_mult_linear(Xts1, yts1)
beta0_ts = beta_ts[0]
beta1_ts = beta_ts[1:]
print("beta_test:\n",beta_ts)
print("beta0_test:\n",beta0_ts)
print("beta1_test:\n",beta1_ts)
# Out:
# beta_test:
#  [[ 1.69860429e+03]
#  [-1.46295246e-03]
#  [ 7.15941103e-04]
#  [-3.50720485e+01]
#  [ 3.43541258e+00]
#  [-3.96553545e-01]
#  [-1.01700893e-02]
#  [-2.45475692e-01]
#  [-1.70942022e-01]
#  [ 8.43894468e-02]]
# beta0_test:
#  [[1698.60429185]]
# beta1_test:
#  [[-1.46295246e-03]
#  [ 7.15941103e-04]
#  [-3.50720485e+01]
#  [ 3.43541258e+00]
#  [-3.96553545e-01]
#  [-1.01700893e-02]
#  [-2.45475692e-01]
#  [-1.70942022e-01]
#  [ 8.43894468e-02]]

# %%
nsamp_test = len(Xts1)
ones_test = np.ones((nsamp_test,1))
X_orig_test = Xts1
X_test = np.hstack((ones_test,X_orig_test))
Xmat_test=np.matrix(X_test)
ymat_test=np.matrix(yts1)
ymat_test=np.transpose(ymat_test)

ytrain_pred_test = Xmat_test*beta_ts
lossm_test = np.linalg.norm(np.array(ymat_test - ytrain_pred_test))**2
print("multiple variable loss="+"{:.2e}".format(lossm_test))
# Out:
# multiple variable loss=3.55e+07

# %% [markdown]
# # Fit Data on Keras Model

# %%
df_tr = pd.read_csv('AB_NYC_2019.csv',
                na_values='?',header=None)
df_tr.columns = df_tr.iloc[0]
df_tr = df_tr[1:]
df_tr = df_tr.dropna()
# Out:
# C:\Users\zzw_e\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (0,2,6,7,9,10,11,13,14,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
inputs = ['neighbourhood_group','latitude','longitude','room_type','price',
         'minimum_nights', 'calculated_host_listings_count','availability_365']
Xtr = df[inputs]
scale = StandardScaler()
Xtr = scale.fit_transform(Xtr)
y = df['number_of_reviews'].values
seed = 7
np.random.seed(seed)
Xtr, Xts, ytr, yts = train_test_split(Xtr, y, test_size=0.33, random_state=seed)
print('Xtr:\n',Xtr)
# Out:
# Xtr:
#  [[-0.0202034  -1.81540401  0.53453749 ... -0.10749563 -0.00633438
#    1.93095823]
#  [-2.04794151  0.57957548  2.99789539 ... -0.22251218 -0.04435342
#    1.53722182]
#  [-0.0202034  -1.40733006 -0.20498388 ... -0.1650039  -0.15841052
#   -0.88695918]
#  ...
#  [ 0.67086429  0.51465463 -0.84191889 ...  0.06502919 -0.15841052
#    1.63758601]
#  [-0.0202034  -0.79631023  0.95837554 ... -0.1650039  -0.15841052
#    1.65302665]
#  [-0.0202034  -1.99179962 -1.19829409 ... -0.1650039  -0.15841052
#    1.35965443]]

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras import metrics
from keras import backend as K
from keras.wrappers.scikit_learn import KerasRegressor
# Out:
# C:\Users\zzw_e\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# ## Create Keras Model

# %%
def create_model():
    # create model
    model = Sequential()
    model.add(Dense(10, input_dim=Xtr.shape[1], activation='relu'))
    model.add(Dense(30, activation='relu'))
    model.add(Dense(40, activation='relu'))
    model.add(Dense(1))
    # Compile model
    model.compile(optimizer ='adam', loss = 'mean_squared_error', 
              metrics =[metrics.mae])
    return model

# %%
model = create_model()
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\zzw_e\Anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 10)                90
# _________________________________________________________________
# dense_2 (Dense)              (None, 30)                330
# _________________________________________________________________
# dense_3 (Dense)              (None, 40)                1240
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 41
# =================================================================
# Total params: 1,701
# Trainable params: 1,701
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(Xtr, ytr, validation_data=(Xts,yts), epochs=150, batch_size=32)
# Out:
# WARNING:tensorflow:From C:\Users\zzw_e\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 26010 samples, validate on 12811 samples
# Epoch 1/150
# 26010/26010 [==============================] - 2s 63us/step - loss: 2395.5245 - mean_absolute_error: 29.1518 - val_loss: 2090.6093 - val_mean_absolute_error: 29.4690
# Epoch 2/150
# 26010/26010 [==============================] - 1s 53us/step - loss: 2168.0295 - mean_absolute_error: 28.9315 - val_loss: 2056.8095 - val_mean_absolute_error: 29.1654
# Epoch 3/150
# 26010/26010 [==============================] - 1s 57us/step - loss: 2137.1888 - mean_absolute_error: 28.4907 - val_loss: 2026.8145 - val_mean_absolute_error: 27.6558
# Epoch 4/150
# 26010/26010 [==============================] - 2s 65us/step - loss: 2100.7368 - mean_absolute_error: 28.0314 - val_loss: 1991.9234 - val_mean_absolute_error: 27.3685
# Epoch 5/150
# 26010/26010 [==============================] - 2s 59us/step - loss: 2068.2841 - mean_absolute_error: 27.7662 - val_loss: 1976.7864 - val_mean_absolute_error: 28.3443
# Epoch 6/150
# 26010/26010 [==============================] - 1s 50us/step - loss: 2051.7060 - mean_absolute_error: 27.6800 - val_loss: 1959.2103 - val_mean_absolute_error: 27.3580
# Epoch 7/150
# 26010/26010 [==============================] - 1s 50us/step - loss: 2038.1304 - mean_absolute_error: 27.5167 - val_loss: 1961.6759 - val_mean_absolute_error: 28.3243
# Epoch 8/150
# 26010/26010 [==============================] - 2s 58us/step - loss: 2027.3188 - mean_absolute_error: 27.4764 - val_loss: 1944.6320 - val_mean_absolute_error: 27.0668
# Epoch 9/150
# 26010/26010 [==============================] - 1s 54us/step - loss: 2017.4709 - mean_absolute_error: 27.3309 - val_loss: 1938.8917 - val_mean_absolute_error: 27.0248
# Epoch 10/150
# 26010/26010 [==============================] - 1s 48us/step - loss: 2008.2409 - mean_absolute_error: 27.2772 - val_loss: 1926.8024 - val_mean_absolute_error: 26.9355
# Epoch 11/150
# 26010/26010 [==============================] - 1s 50us/step - loss: 2002.3738 - mean_absolute_error: 27.2455 - val_loss: 1919.9003 - val_mean_absolute_error: 26.5168
# Epoch 12/150
# 26010/26010 [==============================] - 1s 47us/step - loss: 1993.7243 - mean_absolute_error: 27.1072 - val_loss: 1915.0230 - val_mean_absolute_error: 27.1621
# Epoch 13/150
# 26010/26010 [==============================] - 1s 49us/step - loss: 1986.9010 - mean_absolute_error: 27.0632 - val_loss: 1908.2070 - val_mean_absolute_error: 26.9772
# Epoch 14/150
# 26010/26010 [==============================] - 1s 52us/step - loss: 1982.8308 - mean_absolute_error: 26.9790 - val_loss: 1906.8922 - val_mean_absolute_error: 26.5370
# Epoch 15/150
# 26010/26010 [==============================] - 2s 68us/step - loss: 1978.3160 - mean_absolute_error: 26.8931 - val_loss: 1902.8373 - val_mean_absolute_error: 27.1025
# Epoch 16/150
# 26010/26010 [==============================] - 1s 47us/step - loss: 1971.8877 - mean_absolute_error: 26.8559 - val_loss: 1905.1632 - val_mean_absolute_error: 27.1489
# Epoch 17/150
# 26010/26010 [==============================] - 1s 46us/step - loss: 1969.4707 - mean_absolute_error: 26.7935 - val_loss: 1898.5648 - val_mean_absolute_error: 25.9533
# Epoch 18/150
# 26010/26010 [==============================] - 1s 43us/step - loss: 1968.2676 - mean_absolute_error: 26.7974 - val_loss: 1893.0095 - val_mean_absolute_error: 26.2333
# Epoch 19/150
# 26010/26010 [==============================] - 1s 44us/step - loss: 1962.8694 - mean_absolute_error: 26.7305 - val_loss: 1898.9163 - val_mean_absolute_error: 27.6448
# Epoch 20/150
# 26010/26010 [==============================] - 1s 44us/step - loss: 1963.4136 - mean_absolute_error: 26.7741 - val_loss: 1899.4833 - val_mean_absolute_error: 25.3538
# Epoch 21/150
# 26010/26010 [==============================] - 1s 46us/step - loss: 1960.7722 - mean_absolute_error: 26.6898 - val_loss: 1890.5537 - val_mean_absolute_error: 27.1819
# Epoch 22/150
# 26010/26010 [==============================] - 1s 54us/step - loss: 1958.4512 - mean_absolute_error: 26.6986 - val_loss: 1907.5554 - val_mean_absolute_error: 27.9814
# Epoch 23/150
# 26010/26010 [==============================] - 1s 48us/step - loss: 1956.3454 - mean_absolute_error: 26.6681 - val_loss: 1887.6192 - val_mean_absolute_error: 25.7035
# Epoch 24/150
# 26010/26010 [==============================] - 1s 48us/step - loss: 1952.7713 - mean_absolute_error: 26.6483 - val_loss: 1882.3060 - val_mean_absolute_error: 26.2542
# Epoch 25/150
# 26010/26010 [==============================] - 1s 46us/step - loss: 1953.7999 - mean_absolute_error: 26.6108 - val_loss: 1886.3936 - val_mean_absolute_error: 26.7570
# Epoch 26/150
# 26010/26010 [==============================] - 1s 46us/step - loss: 1949.5411 - mean_absolute_error: 26.6256 - val_loss: 1896.2257 - val_mean_absolute_error: 27.2971
# Epoch 27/150
# 26010/26010 [==============================] - 1s 53us/step - loss: 1952.1232 - mean_absolute_error: 26.6174 - val_loss: 1884.9401 - val_mean_absolute_error: 27.3656
# Epoch 28/150
# 26010/26010 [==============================] - 1s 56us/step - loss: 1951.1676 - mean_absolute_error: 26.6278 - val_loss: 1878.3419 - val_mean_absolute_error: 26.4676
# Epoch 29/150
# 26010/26010 [==============================] - 1s 50us/step - loss: 1945.9725 - mean_absolute_error: 26.5849 - val_loss: 1880.7230 - val_mean_absolute_error: 26.5030
# Epoch 30/150
# 26010/26010 [==============================] - 1s 48us/step - loss: 1945.8806 - mean_absolute_error: 26.5700 - val_loss: 1880.5770 - val_mean_absolute_error: 26.9285
# Epoch 31/150
# 26010/26010 [==============================] - 1s 53us/step - loss: 1942.4706 - mean_absolute_error: 26.5311 - val_loss: 1876.2442 - val_mean_absolute_error: 26.9982
# Epoch 32/150
# 26010/26010 [==============================] - 1s 50us/step - loss: 1942.4578 - mean_absolute_error: 26.5283 - val_loss: 1891.0036 - val_mean_absolute_error: 28.0176
# Epoch 33/150
# 26010/26010 [==============================] - 1s 52us/step - loss: 1941.8375 - mean_absolute_error: 26.5625 - val_loss: 1895.5056 - val_mean_absolute_error: 25.0598
# Epoch 34/150
# 26010/26010 [==============================] - 2s 60us/step - loss: 1941.8268 - mean_absolute_error: 26.5298 - val_loss: 1871.8303 - val_mean_absolute_error: 25.8427
# Epoch 35/150
# 26010/26010 [==============================] - 2s 59us/step - loss: 1940.5161 - mean_absolute_error: 26.5054 - val_loss: 1869.3923 - val_mean_absolute_error: 26.1494
# Epoch 36/150
# 26010/26010 [==============================] - 1s 57us/step - loss: 1941.3164 - mean_absolute_error: 26.4727 - val_loss: 1878.4025 - val_mean_absolute_error: 27.3971
# Epoch 37/150
# 26010/26010 [==============================] - 1s 54us/step - loss: 1937.3824 - mean_absolute_error: 26.4737 - val_loss: 1886.9455 - val_mean_absolute_error: 27.1800
# Epoch 38/150
# 26010/26010 [==============================] - 1s 53us/step - loss: 1934.6574 - mean_absolute_error: 26.4976 - val_loss: 1872.5348 - val_mean_absolute_error: 26.6474
# Epoch 39/150
# 26010/26010 [==============================] - 2s 65us/step - loss: 1935.8771 - mean_absolute_error: 26.4666 - val_loss: 1869.9511 - val_mean_absolute_error: 25.7489
# Epoch 40/150
# 26010/26010 [==============================] - 1s 54us/step - loss: 1936.6669 - mean_absolute_error: 26.4899 - val_loss: 1874.1963 - val_mean_absolute_error: 26.6006
# Epoch 41/150
# 26010/26010 [==============================] - 1s 55us/step - loss: 1933.0892 - mean_absolute_error: 26.4511 - val_loss: 1874.9695 - val_mean_absolute_error: 26.9324
# Epoch 42/150
# 26010/26010 [==============================] - 2s 61us/step - loss: 1930.6513 - mean_absolute_error: 26.4544 - val_loss: 1867.2928 - val_mean_absolute_error: 25.8675
# Epoch 43/150
# 26010/26010 [==============================] - 1s 53us/step - loss: 1929.8446 - mean_absolute_error: 26.3988 - val_loss: 1871.4543 - val_mean_absolute_error: 26.7459
# Epoch 44/150
# 26010/26010 [==============================] - 1s 57us/step - loss: 1928.8253 - mean_absolute_error: 26.3855 - val_loss: 1883.2012 - val_mean_absolute_error: 27.7777
# Epoch 45/150
# 26010/26010 [==============================] - 1s 52us/step - loss: 1931.0964 - mean_absolute_error: 26.4800 - val_loss: 1867.7792 - val_mean_absolute_error: 26.6268
# Epoch 46/150
# 26010/26010 [==============================] - 1s 53us/step - loss: 1926.4708 - mean_absolute_error: 26.3921 - val_loss: 1862.0643 - val_mean_absolute_error: 25.8969
# Epoch 47/150
# 26010/26010 [==============================] - 1s 46us/step - loss: 1929.5146 - mean_absolute_error: 26.4062 - val_loss: 1864.6947 - val_mean_absolute_error: 26.7886
# Epoch 48/150
# 26010/26010 [==============================] - 1s 47us/step - loss: 1926.1182 - mean_absolute_error: 26.3658 - val_loss: 1863.9270 - val_mean_absolute_error: 26.6221
# Epoch 49/150
# 26010/26010 [==============================] - 1s 53us/step - loss: 1922.6718 - mean_absolute_error: 26.3446 - val_loss: 1857.9734 - val_mean_absolute_error: 26.0655
# Epoch 50/150
# 26010/26010 [==============================] - 2s 59us/step - loss: 1922.6052 - mean_absolute_error: 26.3326 - val_loss: 1878.6868 - val_mean_absolute_error: 27.4141
# Epoch 51/150
# 26010/26010 [==============================] - 2s 66us/step - loss: 1921.2238 - mean_absolute_error: 26.3754 - val_loss: 1864.2701 - val_mean_absolute_error: 25.9726
# Epoch 52/150
# 26010/26010 [==============================] - 1s 56us/step - loss: 1920.4859 - mean_absolute_error: 26.3189 - val_loss: 1866.0564 - val_mean_absolute_error: 25.6214
# Epoch 53/150
# 26010/26010 [==============================] - 1s 56us/step - loss: 1922.7125 - mean_absolute_error: 26.3284 - val_loss: 1871.7011 - val_mean_absolute_error: 27.4120
# Epoch 54/150
# 26010/26010 [==============================] - 2s 63us/step - loss: 1919.0996 - mean_absolute_error: 26.3274 - val_loss: 1857.5252 - val_mean_absolute_error: 25.7766
# Epoch 55/150
# 26010/26010 [==============================] - 3s 126us/step - loss: 1920.2403 - mean_absolute_error: 26.3303 - val_loss: 1853.4296 - val_mean_absolute_error: 26.1011
# Epoch 56/150
# 26010/26010 [==============================] - 2s 93us/step - loss: 1919.8825 - mean_absolute_error: 26.3749 - val_loss: 1869.4131 - val_mean_absolute_error: 27.1522
# Epoch 57/150
# 26010/26010 [==============================] - 2s 75us/step - loss: 1917.8353 - mean_absolute_error: 26.3097 - val_loss: 1863.2381 - val_mean_absolute_error: 25.4366
# Epoch 58/150
# 26010/26010 [==============================] - 2s 72us/step - loss: 1915.8174 - mean_absolute_error: 26.2934 - val_loss: 1860.4124 - val_mean_absolute_error: 25.6532
# Epoch 59/150
# 26010/26010 [==============================] - 2s 63us/step - loss: 1917.7113 - mean_absolute_error: 26.3108 - val_loss: 1881.9662 - val_mean_absolute_error: 24.8252
# Epoch 60/150
# 26010/26010 [==============================] - 1s 51us/step - loss: 1916.4408 - mean_absolute_error: 26.2927 - val_loss: 1871.0910 - val_mean_absolute_error: 27.4270
# Epoch 61/150
# 26010/26010 [==============================] - 1s 49us/step - loss: 1911.3032 - mean_absolute_error: 26.2606 - val_loss: 1871.6994 - val_mean_absolute_error: 27.8576
# Epoch 62/150
# 26010/26010 [==============================] - 2s 78us/step - loss: 1913.1408 - mean_absolute_error: 26.2744 - val_loss: 1858.0145 - val_mean_absolute_error: 25.6477
# Epoch 63/150
# 26010/26010 [==============================] - 1s 57us/step - loss: 1915.1684 - mean_absolute_error: 26.2633 - val_loss: 1855.6333 - val_mean_absolute_error: 26.0692
# Epoch 64/150
# 26010/26010 [==============================] - 1s 49us/step - loss: 1912.4828 - mean_absolute_error: 26.2504 - val_loss: 1852.7171 - val_mean_absolute_error: 26.3960
# Epoch 65/150
# 26010/26010 [==============================] - 1s 53us/step - loss: 1911.5614 - mean_absolute_error: 26.2269 - val_loss: 1850.1669 - val_mean_absolute_error: 26.1391
# Epoch 66/150
# 26010/26010 [==============================] - 2s 89us/step - loss: 1906.3184 - mean_absolute_error: 26.1859 - val_loss: 1909.7687 - val_mean_absolute_error: 27.8290
# Epoch 67/150
# 26010/26010 [==============================] - 2s 66us/step - loss: 1911.8161 - mean_absolute_error: 26.2943 - val_loss: 1856.4381 - val_mean_absolute_error: 26.0918
# Epoch 68/150
# 26010/26010 [==============================] - 2s 68us/step - loss: 1909.2194 - mean_absolute_error: 26.2023 - val_loss: 1854.9994 - val_mean_absolute_error: 26.6054
# Epoch 69/150
# 26010/26010 [==============================] - 2s 83us/step - loss: 1907.4425 - mean_absolute_error: 26.2205 - val_loss: 1853.9326 - val_mean_absolute_error: 26.6039
# Epoch 70/150
# 26010/26010 [==============================] - 2s 68us/step - loss: 1909.1684 - mean_absolute_error: 26.2571 - val_loss: 1881.0416 - val_mean_absolute_error: 25.9120
# Epoch 71/150
# 26010/26010 [==============================] - 1s 57us/step - loss: 1909.7335 - mean_absolute_error: 26.1692 - val_loss: 1853.5027 - val_mean_absolute_error: 26.6153
# Epoch 72/150
# 26010/26010 [==============================] - 1s 47us/step - loss: 1910.4542 - mean_absolute_error: 26.2583 - val_loss: 1857.9936 - val_mean_absolute_error: 25.1854
# Epoch 73/150
# 26010/26010 [==============================] - 1s 47us/step - loss: 1908.8348 - mean_absolute_error: 26.1721 - val_loss: 1853.0956 - val_mean_absolute_error: 26.2770
# Epoch 74/150
# 26010/26010 [==============================] - 1s 46us/step - loss: 1905.7975 - mean_absolute_error: 26.1758 - val_loss: 1848.4126 - val_mean_absolute_error: 25.7644
# Epoch 75/150
# 26010/26010 [==============================] - 1s 47us/step - loss: 1906.4539 - mean_absolute_error: 26.1932 - val_loss: 1849.9436 - val_mean_absolute_error: 25.6659
# Epoch 76/150
# 26010/26010 [==============================] - 1s 47us/step - loss: 1905.9524 - mean_absolute_error: 26.2091 - val_loss: 1855.7014 - val_mean_absolute_error: 26.4179
# Epoch 77/150
# 26010/26010 [==============================] - 1s 49us/step - loss: 1905.9810 - mean_absolute_error: 26.2312 - val_loss: 1848.2973 - val_mean_absolute_error: 26.4777
# Epoch 78/150
# 26010/26010 [==============================] - 1s 48us/step - loss: 1902.5185 - mean_absolute_error: 26.1661 - val_loss: 1859.3585 - val_mean_absolute_error: 26.3960
# Epoch 79/150
# 26010/26010 [==============================] - 1s 51us/step - loss: 1903.5510 - mean_absolute_error: 26.2098 - val_loss: 1870.8106 - val_mean_absolute_error: 26.2951
# Epoch 80/150
# 26010/26010 [==============================] - 1s 57us/step - loss: 1904.5649 - mean_absolute_error: 26.1742 - val_loss: 1859.8475 - val_mean_absolute_error: 26.8416
# Epoch 81/150
# 26010/26010 [==============================] - 1s 53us/step - loss: 1902.0676 - mean_absolute_error: 26.1440 - val_loss: 1850.1080 - val_mean_absolute_error: 25.4661
# Epoch 82/150
# 26010/26010 [==============================] - 1s 53us/step - loss: 1903.9166 - mean_absolute_error: 26.1347 - val_loss: 1852.9688 - val_mean_absolute_error: 26.4137
# Epoch 83/150
# 26010/26010 [==============================] - 1s 47us/step - loss: 1902.7939 - mean_absolute_error: 26.1852 - val_loss: 1852.8224 - val_mean_absolute_error: 26.6511
# Epoch 84/150
# 26010/26010 [==============================] - 1s 49us/step - loss: 1901.5623 - mean_absolute_error: 26.1577 - val_loss: 1854.8043 - val_mean_absolute_error: 26.8325
# Epoch 85/150
# 26010/26010 [==============================] - 1s 41us/step - loss: 1902.7458 - mean_absolute_error: 26.1943 - val_loss: 1853.9582 - val_mean_absolute_error: 25.9196
# Epoch 86/150
# 26010/26010 [==============================] - 1s 46us/step - loss: 1899.7518 - mean_absolute_error: 26.1654 - val_loss: 1855.2488 - val_mean_absolute_error: 25.0974
# Epoch 87/150
# 26010/26010 [==============================] - 1s 51us/step - loss: 1899.5136 - mean_absolute_error: 26.1163 - val_loss: 1858.7839 - val_mean_absolute_error: 27.1320
# Epoch 88/150
# 26010/26010 [==============================] - 1s 51us/step - loss: 1896.4135 - mean_absolute_error: 26.0973 - val_loss: 1860.0506 - val_mean_absolute_error: 25.9633
# Epoch 89/150
# 26010/26010 [==============================] - 1s 52us/step - loss: 1901.4216 - mean_absolute_error: 26.1268 - val_loss: 1852.6878 - val_mean_absolute_error: 26.9074
# Epoch 90/150
# 26010/26010 [==============================] - 1s 49us/step - loss: 1897.5819 - mean_absolute_error: 26.1737 - val_loss: 1858.3520 - val_mean_absolute_error: 25.7077
# Epoch 91/150
# 26010/26010 [==============================] - 1s 49us/step - loss: 1898.3499 - mean_absolute_error: 26.1170 - val_loss: 1871.1265 - val_mean_absolute_error: 27.5324
# Epoch 92/150
# 26010/26010 [==============================] - 1s 55us/step - loss: 1897.0490 - mean_absolute_error: 26.1168 - val_loss: 1847.3297 - val_mean_absolute_error: 26.1155
# Epoch 93/150
# 26010/26010 [==============================] - 1s 51us/step - loss: 1894.8166 - mean_absolute_error: 26.1249 - val_loss: 1876.4159 - val_mean_absolute_error: 27.1848
# Epoch 94/150
# 26010/26010 [==============================] - 1s 51us/step - loss: 1893.6604 - mean_absolute_error: 26.1124 - val_loss: 1854.0305 - val_mean_absolute_error: 25.8398
# Epoch 95/150
# 26010/26010 [==============================] - 1s 50us/step - loss: 1894.4687 - mean_absolute_error: 26.0828 - val_loss: 1846.8864 - val_mean_absolute_error: 25.7735
# Epoch 96/150
# 26010/26010 [==============================] - 1s 48us/step - loss: 1896.4808 - mean_absolute_error: 26.0830 - val_loss: 1845.8894 - val_mean_absolute_error: 25.7595
# Epoch 97/150
# 26010/26010 [==============================] - 1s 51us/step - loss: 1894.9310 - mean_absolute_error: 26.1177 - val_loss: 1843.8527 - val_mean_absolute_error: 25.5319
# Epoch 98/150
# 26010/26010 [==============================] - 1s 49us/step - loss: 1893.8965 - mean_absolute_error: 26.0966 - val_loss: 1840.9367 - val_mean_absolute_error: 25.7964
# Epoch 99/150
# 26010/26010 [==============================] - 1s 49us/step - loss: 1894.4865 - mean_absolute_error: 26.0523 - val_loss: 1847.6436 - val_mean_absolute_error: 26.5692
# Epoch 100/150
# 26010/26010 [==============================] - 1s 49us/step - loss: 1893.8099 - mean_absolute_error: 26.0502 - val_loss: 1845.8488 - val_mean_absolute_error: 26.6067
# Epoch 101/150
# 26010/26010 [==============================] - 1s 47us/step - loss: 1895.1366 - mean_absolute_error: 26.0906 - val_loss: 1854.9858 - val_mean_absolute_error: 27.0470
# Epoch 102/150
# 26010/26010 [==============================] - 1s 43us/step - loss: 1891.0413 - mean_absolute_error: 26.0615 - val_loss: 1844.3784 - val_mean_absolute_error: 26.1686
# Epoch 103/150
# 26010/26010 [==============================] - 1s 46us/step - loss: 1891.2288 - mean_absolute_error: 26.0540 - val_loss: 1867.4166 - val_mean_absolute_error: 27.0330
# Epoch 104/150
# 26010/26010 [==============================] - 1s 47us/step - loss: 1889.8636 - mean_absolute_error: 26.0731 - val_loss: 1870.3987 - val_mean_absolute_error: 27.6746
# Epoch 105/150
# 26010/26010 [==============================] - 1s 49us/step - loss: 1888.7529 - mean_absolute_error: 26.0391 - val_loss: 1842.6458 - val_mean_absolute_error: 25.8752
# Epoch 106/150
# 26010/26010 [==============================] - 1s 43us/step - loss: 1892.0892 - mean_absolute_error: 26.0859 - val_loss: 1858.5125 - val_mean_absolute_error: 27.0493
# Epoch 107/150
# 26010/26010 [==============================] - 1s 44us/step - loss: 1889.6163 - mean_absolute_error: 26.0745 - val_loss: 1856.1692 - val_mean_absolute_error: 27.1064
# Epoch 108/150
# 26010/26010 [==============================] - 1s 43us/step - loss: 1888.5463 - mean_absolute_error: 26.0476 - val_loss: 1843.4587 - val_mean_absolute_error: 26.0229
# Epoch 109/150
# 26010/26010 [==============================] - 1s 43us/step - loss: 1887.6921 - mean_absolute_error: 26.0294 - val_loss: 1846.4952 - val_mean_absolute_error: 26.5446
# Epoch 110/150
# 26010/26010 [==============================] - 1s 42us/step - loss: 1885.6367 - mean_absolute_error: 26.0030 - val_loss: 1843.4629 - val_mean_absolute_error: 25.5368
# Epoch 111/150
# 26010/26010 [==============================] - 1s 43us/step - loss: 1886.0564 - mean_absolute_error: 26.0223 - val_loss: 1851.6067 - val_mean_absolute_error: 25.4529
# Epoch 112/150
# 26010/26010 [==============================] - 1s 56us/step - loss: 1887.8989 - mean_absolute_error: 26.0329 - val_loss: 1852.9387 - val_mean_absolute_error: 25.8721
# Epoch 113/150
# 26010/26010 [==============================] - 1s 54us/step - loss: 1885.4397 - mean_absolute_error: 26.0465 - val_loss: 1843.3053 - val_mean_absolute_error: 26.0387
# Epoch 114/150
# 26010/26010 [==============================] - 1s 54us/step - loss: 1886.5212 - mean_absolute_error: 26.0011 - val_loss: 1845.9357 - val_mean_absolute_error: 26.7608
# Epoch 115/150
# 26010/26010 [==============================] - 1s 53us/step - loss: 1885.6712 - mean_absolute_error: 26.0272 - val_loss: 1836.2207 - val_mean_absolute_error: 26.3549
# Epoch 116/150
# 26010/26010 [==============================] - 1s 48us/step - loss: 1885.1161 - mean_absolute_error: 26.0484 - val_loss: 1849.8570 - val_mean_absolute_error: 26.1793
# Epoch 117/150
# 26010/26010 [==============================] - 2s 74us/step - loss: 1883.3814 - mean_absolute_error: 26.0044 - val_loss: 1838.6246 - val_mean_absolute_error: 26.0102
# Epoch 118/150
# 26010/26010 [==============================] - 2s 68us/step - loss: 1883.1704 - mean_absolute_error: 25.9817 - val_loss: 1848.2219 - val_mean_absolute_error: 25.9345
# Epoch 119/150
# 26010/26010 [==============================] - 2s 62us/step - loss: 1883.4387 - mean_absolute_error: 26.0415 - val_loss: 1839.3256 - val_mean_absolute_error: 25.8473
# Epoch 120/150
# 26010/26010 [==============================] - 1s 57us/step - loss: 1881.9228 - mean_absolute_error: 25.9950 - val_loss: 1837.3954 - val_mean_absolute_error: 26.4131
# Epoch 121/150
# 26010/26010 [==============================] - 1s 56us/step - loss: 1882.0450 - mean_absolute_error: 26.0486 - val_loss: 1839.4968 - val_mean_absolute_error: 25.2874
# Epoch 122/150
# 26010/26010 [==============================] - 1s 51us/step - loss: 1880.6927 - mean_absolute_error: 25.9402 - val_loss: 1839.5701 - val_mean_absolute_error: 26.6962
# Epoch 123/150
# 26010/26010 [==============================] - 1s 57us/step - loss: 1881.2044 - mean_absolute_error: 26.0013 - val_loss: 1837.6736 - val_mean_absolute_error: 25.7080
# Epoch 124/150
# 26010/26010 [==============================] - 1s 43us/step - loss: 1882.3452 - mean_absolute_error: 25.9719 - val_loss: 1841.0054 - val_mean_absolute_error: 26.6027
# Epoch 125/150
# 26010/26010 [==============================] - 1s 43us/step - loss: 1880.5481 - mean_absolute_error: 25.9633 - val_loss: 1833.3106 - val_mean_absolute_error: 25.7496
# Epoch 126/150
# 26010/26010 [==============================] - 1s 45us/step - loss: 1880.2134 - mean_absolute_error: 25.9960 - val_loss: 1845.6935 - val_mean_absolute_error: 26.2775
# Epoch 127/150
# 26010/26010 [==============================] - 1s 49us/step - loss: 1880.4717 - mean_absolute_error: 25.9585 - val_loss: 1857.6582 - val_mean_absolute_error: 24.9332
# Epoch 128/150
# 26010/26010 [==============================] - 2s 66us/step - loss: 1882.0204 - mean_absolute_error: 25.9800 - val_loss: 1832.5851 - val_mean_absolute_error: 26.2626
# Epoch 129/150
# 26010/26010 [==============================] - 2s 65us/step - loss: 1878.4370 - mean_absolute_error: 25.9738 - val_loss: 1847.3512 - val_mean_absolute_error: 26.1360
# Epoch 130/150
# 26010/26010 [==============================] - 1s 53us/step - loss: 1875.6867 - mean_absolute_error: 25.9596 - val_loss: 1834.6927 - val_mean_absolute_error: 25.7406
# Epoch 131/150
# 26010/26010 [==============================] - 1s 57us/step - loss: 1877.5444 - mean_absolute_error: 25.9240 - val_loss: 1879.9842 - val_mean_absolute_error: 27.8660
# Epoch 132/150
# 26010/26010 [==============================] - 1s 47us/step - loss: 1875.7202 - mean_absolute_error: 25.9454 - val_loss: 1834.7591 - val_mean_absolute_error: 26.0217
# Epoch 133/150
# 26010/26010 [==============================] - 1s 47us/step - loss: 1878.2767 - mean_absolute_error: 25.9246 - val_loss: 1838.7713 - val_mean_absolute_error: 26.2444
# Epoch 134/150
# 26010/26010 [==============================] - 1s 48us/step - loss: 1875.3770 - mean_absolute_error: 25.8882 - val_loss: 1853.6991 - val_mean_absolute_error: 27.5393
# Epoch 135/150
# 26010/26010 [==============================] - 1s 48us/step - loss: 1878.1262 - mean_absolute_error: 25.9696 - val_loss: 1841.1557 - val_mean_absolute_error: 26.2563
# Epoch 136/150
# 26010/26010 [==============================] - 1s 46us/step - loss: 1878.2137 - mean_absolute_error: 25.9708 - val_loss: 1832.5685 - val_mean_absolute_error: 25.6105
# Epoch 137/150
# 26010/26010 [==============================] - 1s 45us/step - loss: 1875.6863 - mean_absolute_error: 25.8852 - val_loss: 1835.6668 - val_mean_absolute_error: 25.4968
# Epoch 138/150
# 26010/26010 [==============================] - 1s 45us/step - loss: 1876.9228 - mean_absolute_error: 25.9646 - val_loss: 1838.1903 - val_mean_absolute_error: 25.1328
# Epoch 139/150
# 26010/26010 [==============================] - 1s 46us/step - loss: 1876.8998 - mean_absolute_error: 25.9558 - val_loss: 1835.1275 - val_mean_absolute_error: 25.1612
# Epoch 140/150
# 26010/26010 [==============================] - 1s 48us/step - loss: 1875.7790 - mean_absolute_error: 25.9103 - val_loss: 1852.6025 - val_mean_absolute_error: 27.5752
# Epoch 141/150
# 26010/26010 [==============================] - 1s 52us/step - loss: 1876.3189 - mean_absolute_error: 25.9309 - val_loss: 1834.5222 - val_mean_absolute_error: 25.9691
# Epoch 142/150
# 26010/26010 [==============================] - 2s 59us/step - loss: 1876.6581 - mean_absolute_error: 25.9496 - val_loss: 1834.3481 - val_mean_absolute_error: 25.7034
# Epoch 143/150
# 26010/26010 [==============================] - 1s 51us/step - loss: 1874.0561 - mean_absolute_error: 25.9123 - val_loss: 1834.9186 - val_mean_absolute_error: 25.4749
# Epoch 144/150
# 26010/26010 [==============================] - 1s 51us/step - loss: 1874.9553 - mean_absolute_error: 25.9248 - val_loss: 1838.1714 - val_mean_absolute_error: 25.8493
# Epoch 145/150
# 26010/26010 [==============================] - 1s 47us/step - loss: 1871.6060 - mean_absolute_error: 25.9375 - val_loss: 1837.8334 - val_mean_absolute_error: 26.0339
# Epoch 146/150
# 26010/26010 [==============================] - 1s 45us/step - loss: 1872.3991 - mean_absolute_error: 25.9029 - val_loss: 1855.5464 - val_mean_absolute_error: 26.3015
# Epoch 147/150
# 26010/26010 [==============================] - 1s 45us/step - loss: 1874.3140 - mean_absolute_error: 25.9331 - val_loss: 1872.0686 - val_mean_absolute_error: 24.5275
# Epoch 148/150
# 26010/26010 [==============================] - 1s 45us/step - loss: 1875.2316 - mean_absolute_error: 25.8952 - val_loss: 1849.8717 - val_mean_absolute_error: 26.4960
# Epoch 149/150
# 26010/26010 [==============================] - 1s 46us/step - loss: 1871.5286 - mean_absolute_error: 25.9224 - val_loss: 1847.5648 - val_mean_absolute_error: 24.9975
# Epoch 150/150
# 26010/26010 [==============================] - 1s 46us/step - loss: 1871.9754 - mean_absolute_error: 25.8640 - val_loss: 1838.9086 - val_mean_absolute_error: 26.2024

# %% [markdown]
# ## Evaluation Model Performence

# %%
# Accuracy summary of Keras Model
plt.plot(hist.history['mean_absolute_error'])
plt.plot(hist.history['val_mean_absolute_error'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Loss summary of Keras Model
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Make Prediction on Testing Set

# %%
prediction = model.predict(Xts)
Xts_new = scale.inverse_transform(Xts)
result = {}
for i in range(len(inputs)):
    result[inputs[i]] = Xts_new[:,i]
result['number_of_reviews'] = prediction[:,0]

# %%
pd.DataFrame(result)
# Out:
#        neighbourhood_group  latitude  longitude  room_type  price  \
# 0                    848.0  40.63581  -73.96977        0.0   40.0
# 1                    848.0  40.67809  -73.95903        0.0   62.0
# 2                    924.0  40.75649  -73.97126        1.0  160.0
# 3                    924.0  40.75229  -73.99550        1.0  250.0
# 4                    848.0  40.58198  -73.95770        0.0   35.0
# 5                    924.0  40.75417  -73.96557        1.0  737.0
# 6                    848.0  40.65129  -73.94058        0.0   90.0
# 7                    848.0  40.68382  -73.95566        1.0  300.0
# 8                    848.0  40.69182  -73.92859        0.0   52.0
# 9                    924.0  40.74915  -73.97610        1.0  220.0
# 10                   924.0  40.75946  -73.99083        0.0   70.0
# 11                   848.0  40.63498  -74.01966        0.0   75.0
# 12                   848.0  40.70158  -73.92724        0.0  100.0
# 13                   625.0  40.76189  -73.77349        1.0  120.0
# 14                   924.0  40.70234  -74.01047        1.0  130.0
# 15                   924.0  40.76038  -73.98781        1.0  219.0
# 16                   924.0  40.80651  -73.93776        2.0   60.0
# 17                   924.0  40.73045  -74.00266        0.0   90.0
# 18                   848.0  40.69436  -73.92530        1.0   55.0
# 19                   848.0  40.68822  -73.91639        0.0   64.0
# 20                   848.0  40.67172  -73.95031        1.0   50.0
# 21                   848.0  40.69845  -73.93495        0.0   30.0
# 22                   848.0  40.66535  -73.88910        0.0   40.0
# 23                   924.0  40.74835  -73.97612        1.0  244.0
# 24                   924.0  40.79370  -73.96590        1.0  185.0
# 25                   924.0  40.81808  -73.93671        0.0   45.0
# 26                   625.0  40.74321  -73.95533        1.0  260.0
# 27                   848.0  40.66526  -73.98449        0.0  100.0
# 28                   924.0  40.85618  -73.93085        0.0   44.0
# 29                   924.0  40.73089  -73.98195        1.0  160.0
# ...                    ...       ...        ...        ...    ...
# 12781                924.0  40.76128  -73.96463        1.0  485.0
# 12782                924.0  40.71611  -73.99828        0.0  110.0
# 12783                848.0  40.68765  -73.90821        0.0   75.0
# 12784                924.0  40.77041  -73.96109        1.0  300.0
# 12785                924.0  40.80255  -73.94349        1.0  300.0
# 12786                924.0  40.80903  -73.94307        0.0   97.0
# 12787                924.0  40.80630  -73.94540        0.0  105.0
# 12788                848.0  40.63931  -73.94451        0.0  125.0
# 12789                924.0  40.85413  -73.93172        0.0   45.0
# 12790                848.0  40.68425  -73.96455        1.0  100.0
# 12791                924.0  40.71179  -73.99848        0.0  160.0
# 12792                924.0  40.76022  -73.99253        1.0  395.0
# 12793                848.0  40.70504  -73.91868        1.0  120.0
# 12794                848.0  40.68440  -73.96221        1.0  190.0
# 12795                924.0  40.74832  -73.98915        0.0  130.0
# 12796                924.0  40.78128  -73.98184        1.0  149.0
# 12797                848.0  40.73757  -73.95509        1.0   80.0
# 12798                848.0  40.63863  -74.01916        1.0   88.0
# 12799                625.0  40.76112  -73.92631        1.0   79.0
# 12800                848.0  40.64837  -73.96180        1.0   88.0
# 12801                924.0  40.77660  -73.94862        1.0  275.0
# 12802                924.0  40.80442  -73.95629        0.0   60.0
# 12803                848.0  40.68701  -73.91437        1.0   84.0
# 12804                848.0  40.69887  -73.93564        1.0   75.0
# 12805                924.0  40.86821  -73.92128        0.0   76.0
# 12806                625.0  40.75236  -73.75519        0.0   41.0
# 12807                848.0  40.70908  -73.95006        0.0   78.0
# 12808                848.0  40.69452  -73.92840        0.0   42.0
# 12809                625.0  40.75733  -73.94176        0.0   55.0
# 12810                924.0  40.81024  -73.95250        0.0   95.0
#
#        minimum_nights  calculated_host_listings_count  availability_365  \
# 0                 2.0                             1.0               6.0
# 1                 4.0                             1.0               0.0
# 2                 4.0                             1.0               0.0
# 3                 2.0                             1.0               0.0
# 4                 1.0                             5.0             186.0
# 5                 3.0                            49.0             188.0
# 6                 1.0                             1.0             365.0
# 7                 2.0                             1.0               0.0
# 8                 2.0                             8.0             268.0
# 9                30.0                             1.0             310.0
# 10                1.0                             1.0               0.0
# 11                1.0                             1.0               0.0
# 12                1.0                             5.0             324.0
# 13                2.0                             1.0              41.0
# 14                2.0                             1.0              85.0
# 15                7.0                             1.0             235.0
# 16                1.0                             1.0               0.0
# 17                2.0                             1.0               0.0
# 18                1.0                             4.0              64.0
# 19                2.0                            10.0             352.0
# 20                3.0                             1.0               0.0
# 21                1.0                             3.0               0.0
# 22                1.0                             5.0              36.0
# 23                2.0                           327.0             133.0
# 24               30.0                            96.0             310.0
# 25                1.0                             1.0               0.0
# 26               21.0                             1.0              42.0
# 27                2.0                             1.0               0.0
# 28                2.0                             1.0               0.0
# 29               30.0                             1.0              46.0
# ...               ...                             ...               ...
# 12781             7.0                             1.0               0.0
# 12782            30.0                             1.0             281.0
# 12783             1.0                             1.0               0.0
# 12784             2.0                             1.0               8.0
# 12785             3.0                             1.0             272.0
# 12786             1.0                             3.0              75.0
# 12787             4.0                             6.0             119.0
# 12788             1.0                             2.0             364.0
# 12789             3.0                             2.0               0.0
# 12790             3.0                             1.0               8.0
# 12791             2.0                             1.0               3.0
# 12792             2.0                             1.0             247.0
# 12793             3.0                             1.0               3.0
# 12794             2.0                             4.0              12.0
# 12795             1.0                             3.0              81.0
# 12796             2.0                             1.0               0.0
# 12797             2.0                             3.0               5.0
# 12798            14.0                             1.0               0.0
# 12799             3.0                             1.0             105.0
# 12800             4.0                             1.0               0.0
# 12801            30.0                             1.0             196.0
# 12802             1.0                             1.0             132.0
# 12803             2.0                             2.0               6.0
# 12804             6.0                             1.0              53.0
# 12805             2.0                             1.0             352.0
# 12806             2.0                             1.0               0.0
# 12807             1.0                             1.0              30.0
# 12808             1.0                             7.0              61.0
# 12809             2.0                             2.0              81.0
# 12810             1.0                             1.0               0.0
#
#        number_of_reviews
# 0              16.449360
# 1               6.576634
# 2               8.442208
# 3              11.798110
# 4              32.218319
# 5               5.368821
# 6              24.156567
# 7              12.489820
# 8              68.887222
# 9              22.687531
# 10             14.084270
# 11              3.723813
# 12             43.468601
# 13             42.288410
# 14             48.732143
# 15             40.346752
# 16              9.494226
# 17             10.598180
# 18             63.561695
# 19             36.887997
# 20              8.494279
# 21             28.925409
# 22             31.296402
# 23             15.950711
# 24              9.409421
# 25             13.329288
# 26             13.135207
# 27              7.864052
# 28             13.008849
# 29             14.419273
# ...                  ...
# 12781          10.078813
# 12782          19.976864
# 12783          10.177876
# 12784          21.299961
# 12785          61.912220
# 12786          50.701130
# 12787          38.449589
# 12788          23.750175
# 12789          17.509861
# 12790          19.258921
# 12791          17.225796
# 12792          46.790970
# 12793          12.859433
# 12794          33.397133
# 12795          72.480453
# 12796           9.978564
# 12797          22.890766
# 12798          12.893115
# 12799          48.447342
# 12800          10.546784
# 12801          21.693924
# 12802          63.566044
# 12803          26.698929
# 12804          42.941425
# 12805          38.247959
# 12806          50.855122
# 12807          55.421886
# 12808          59.931438
# 12809          40.936142
# 12810          16.672651
#
# [12811 rows x 9 columns]
